# %%
import pandas as pd
from fuzzywuzzy import fuzz
from sklearn.metrics import precision_score, recall_score, f1_score
# Load the datasets
df1 = pd.read_csv('C:/Users/Pranav Palanickal/Downloads/constituents-financials_csv.csv')
df2 = pd.read_csv('C:/Users/Pranav Palanickal/Downloads/sp500_companies.csv')

# Display the first few rows of each dataset to check their structure
print("First Dataset:")
print(df1.head())

print("\nSecond Dataset:")
print(df2.head())
# Out:
# First Dataset:
#   Symbol                 Name                  Sector   Price  Price/Earnings  \
# 0    MMM           3M Company             Industrials  222.89           24.31
# 1    AOS      A.O. Smith Corp             Industrials   60.24           27.76
# 2    ABT  Abbott Laboratories             Health Care   56.27           22.51
# 3   ABBV          AbbVie Inc.             Health Care  108.48           19.41
# 4    ACN        Accenture plc  Information Technology  150.51           25.47
#
#    Dividend Yield  Earnings/Share  52 Week Low  52 Week High    Market Cap  \
# 0        2.332862            7.92       259.77       175.490  138721055226
# 1        1.147959            1.70        68.39        48.925   10783419933
# 2        1.908982            0.26        64.60        42.280  102121042306
# 3        2.499560            3.29       125.86        60.050  181386347059
# 4        1.714470            5.44       162.60       114.820   98765855553
#
#          EBITDA  Price/Sales  Price/Book  \
# 0  9.048000e+09     4.390271       11.34
# 1  6.010000e+08     3.575483        6.35
# 2  5.744000e+09     3.740480        3.19
# 3  1.031000e+10     6.291571       26.14
# 4  5.643228e+09     2.604117       10.62
#
#                                          SEC Filings
# 0  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4  http://www.sec.gov/cgi-bin/browse-edgar?action...
#
# Second Dataset:
#   Exchange Symbol              Shortname               Longname  \
# 0      NMS   AAPL             Apple Inc.             Apple Inc.
# 1      NMS   MSFT  Microsoft Corporation  Microsoft Corporation
# 2      NMS   NVDA     NVIDIA Corporation     NVIDIA Corporation
# 3      NMS  GOOGL          Alphabet Inc.          Alphabet Inc.
# 4      NMS   GOOG          Alphabet Inc.          Alphabet Inc.
#
#                    Sector                        Industry  Currentprice  \
# 0              Technology            Consumer Electronics        229.00
# 1              Technology       Software - Infrastructure        417.14
# 2              Technology                  Semiconductors        119.37
# 3  Communication Services  Internet Content & Information        163.38
# 4  Communication Services  Internet Content & Information        165.11
#
#        Marketcap        Ebitda  Revenuegrowth           City State  \
# 0  3481738936320  1.317810e+11          0.049      Cupertino    CA
# 1  3100618260480  1.294330e+11          0.152        Redmond    WA
# 2  2928146120704  6.118400e+10          1.224    Santa Clara    CA
# 3  2021272190976  1.154780e+11          0.136  Mountain View    CA
# 4  2020401479680  1.154780e+11          0.136  Mountain View    CA
#
#          Country  Fulltimeemployees  \
# 0  United States           161000.0
# 1  United States           228000.0
# 2  United States            29600.0
# 3  United States           179582.0
# 4  United States           179582.0
#
#                                  Longbusinesssummary    Weight
# 0  Apple Inc. designs, manufactures, and markets ...  0.066419
# 1  Microsoft Corporation develops and supports so...  0.059148
# 2  NVIDIA Corporation provides graphics and compu...  0.055858
# 3  Alphabet Inc. offers various products and plat...  0.038558
# 4  Alphabet Inc. offers various products and plat...  0.038542

# %%
# Inspect columns and data types
print("First Dataset Columns and Types:")
print(df1.dtypes)

print("\nSecond Dataset Columns and Types:")
print(df2.dtypes)
# Out:
# First Dataset Columns and Types:
# Unnamed: 0                     int64
# name                          object
# domain                        object
# year founded                 float64
# industry                      object
# size range                    object
# locality                      object
# country                       object
# linkedin url                  object
# current employee estimate      int64
# total employee estimate        int64
# dtype: object
#
# Second Dataset Columns and Types:
# Exchange                object
# Symbol                  object
# Shortname               object
# Longname                object
# Sector                  object
# Industry                object
# Currentprice           float64
# Marketcap                int64
# Ebitda                 float64
# Revenuegrowth          float64
# City                    object
# State                   object
# Country                 object
# Fulltimeemployees      float64
# Longbusinesssummary     object
# Weight                 float64
# dtype: object

# %%
df1 = df1.rename(columns={'Name': 'name'})
df2 = df2.rename(columns={'Shortname': 'name_short', 'Longname': 'name_long'})

# %%
combined_df = pd.merge(df1, df2, on='Symbol', how='outer')

# %%
combined_df.head()
# Out:
#   Symbol                      name                Sector_x   Price  \
# 0      A  Agilent Technologies Inc             Health Care   65.05
# 1    AAL   American Airlines Group             Industrials   48.60
# 2    AAP        Advance Auto Parts  Consumer Discretionary  109.63
# 3   AAPL                Apple Inc.  Information Technology  155.15
# 4   ABBV               AbbVie Inc.             Health Care  108.48
#
#    Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  52 Week High  \
# 0           27.45        0.875698            2.10        75.00         49.23
# 1            9.92        0.778210            3.91        59.08         39.21
# 2           19.54        0.218321            6.19       169.55         78.81
# 3           16.86        1.579541            9.20       180.10        131.12
# 4           19.41        2.499560            3.29       125.86         60.05
#
#      Market Cap  ...  Currentprice     Marketcap        Ebitda Revenuegrowth  \
# 0  2.198461e+10  ...        142.92  4.106492e+10  1.564000e+09        -0.056
# 1  2.459485e+10  ...         10.62  6.974196e+09  5.150000e+09         0.020
# 2  8.123612e+09  ...           NaN           NaN           NaN           NaN
# 3  8.095080e+11  ...        229.00  3.481739e+12  1.317810e+11         0.049
# 4  1.813863e+11  ...        196.31  3.467502e+11  2.612100e+10         0.043
#
#             City State        Country Fulltimeemployees  \
# 0    Santa Clara    CA  United States           17400.0
# 1     Fort Worth    TX  United States          137400.0
# 2            NaN   NaN            NaN               NaN
# 3      Cupertino    CA  United States          161000.0
# 4  North Chicago    IL  United States           50000.0
#
#                                  Longbusinesssummary    Weight
# 0  Agilent Technologies, Inc. provides applicatio...  0.000783
# 1  American Airlines Group Inc., through its subs...  0.000133
# 2                                                NaN       NaN
# 3  Apple Inc. designs, manufactures, and markets ...  0.066419
# 4  AbbVie Inc. discovers, develops, manufactures,...  0.006615
#
# [5 rows x 29 columns]

# %%
# Check for missing values
missing_info = cleaned_df.isnull().sum()
print("Missing Values per Column:")
print(missing_info)
# Out:
# Missing Values per Column:
# Symbol                   0
# name                   129
# Sector_x               129
# Price                  129
# Price/Earnings         131
# Dividend Yield         129
# Earnings/Share         129
# 52 Week Low            129
# 52 Week High           129
# Market Cap             129
# EBITDA                 129
# Price/Sales            129
# Price/Book             137
# SEC Filings            129
# Exchange               131
# name_short             131
# name_long              131
# Sector_y               131
# Industry               131
# Currentprice           131
# Marketcap              131
# Ebitda                 160
# Revenuegrowth          133
# City                   131
# State                  150
# Country                131
# Fulltimeemployees      139
# Longbusinesssummary    131
# Weight                 131
# dtype: int64

# %%
columns_to_drop = ['sector', 'price', 'priceearnings', 'dividend yield', 'any_other_non_essential_columns']
cleaned_df = combined_df.drop(columns=columns_to_drop, errors='ignore')
print("Cleaned Dataset:")
print(cleaned_df.head())
# Out:
# Cleaned Dataset:
#   Symbol                      name                Sector_x   Price  \
# 0      A  Agilent Technologies Inc             Health Care   65.05
# 1    AAL   American Airlines Group             Industrials   48.60
# 2    AAP        Advance Auto Parts  Consumer Discretionary  109.63
# 3   AAPL                Apple Inc.  Information Technology  155.15
# 4   ABBV               AbbVie Inc.             Health Care  108.48
#
#    Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  52 Week High  \
# 0           27.45        0.875698            2.10        75.00         49.23
# 1            9.92        0.778210            3.91        59.08         39.21
# 2           19.54        0.218321            6.19       169.55         78.81
# 3           16.86        1.579541            9.20       180.10        131.12
# 4           19.41        2.499560            3.29       125.86         60.05
#
#      Market Cap  ...  Currentprice     Marketcap        Ebitda Revenuegrowth  \
# 0  2.198461e+10  ...        142.92  4.106492e+10  1.564000e+09        -0.056
# 1  2.459485e+10  ...         10.62  6.974196e+09  5.150000e+09         0.020
# 2  8.123612e+09  ...           NaN           NaN           NaN           NaN
# 3  8.095080e+11  ...        229.00  3.481739e+12  1.317810e+11         0.049
# 4  1.813863e+11  ...        196.31  3.467502e+11  2.612100e+10         0.043
#
#             City State        Country Fulltimeemployees  \
# 0    Santa Clara    CA  United States           17400.0
# 1     Fort Worth    TX  United States          137400.0
# 2            NaN   NaN            NaN               NaN
# 3      Cupertino    CA  United States          161000.0
# 4  North Chicago    IL  United States           50000.0
#
#                                  Longbusinesssummary    Weight
# 0  Agilent Technologies, Inc. provides applicatio...  0.000783
# 1  American Airlines Group Inc., through its subs...  0.000133
# 2                                                NaN       NaN
# 3  Apple Inc. designs, manufactures, and markets ...  0.066419
# 4  AbbVie Inc. discovers, develops, manufactures,...  0.006615
#
# [5 rows x 29 columns]

# %%
# Drop rows where 'symbol' is missing
cleaned_df = cleaned_df.dropna(subset=['Symbol'])

# Drop rows where 'name', 'name_short', or 'name_long' is missing if those columns are essential
cleaned_df = cleaned_df.dropna(subset=['name', 'name_short', 'name_long'])

# %%
# Check for remaining missing values
missing_info = cleaned_df.isnull().sum()
print("Missing Values per Column after dropping rows:")
print(missing_info)
# Out:
# Missing Values per Column after dropping rows:
# Symbol                  0
# name                    0
# Sector_x                0
# Price                   0
# Price/Earnings          1
# Dividend Yield          0
# Earnings/Share          0
# 52 Week Low             0
# 52 Week High            0
# Market Cap              0
# EBITDA                  0
# Price/Sales             0
# Price/Book              6
# SEC Filings             0
# Exchange                0
# name_short              0
# name_long               0
# Sector_y                0
# Industry                0
# Currentprice            0
# Marketcap               0
# Ebitda                 24
# Revenuegrowth           1
# City                    0
# State                  11
# Country                 0
# Fulltimeemployees       5
# Longbusinesssummary     0
# Weight                  0
# dtype: int64

# %%
# Remove duplicate rows based on 'symbol'
cleaned_df = cleaned_df.drop_duplicates(subset='Symbol')

# %%
print("Unique Values in 'name':")
print(cleaned_df['name'].unique())
print("Unique Values in 'name_short':")
print(cleaned_df['name_short'].unique())
print("Unique Values in 'name_long':")
print(cleaned_df['name_long'].unique())
# Out:
# Unique Values in 'name':
# ['Agilent Technologies Inc' 'American Airlines Group' 'Apple Inc.'
#  'AbbVie Inc.' 'Abbott Laboratories' 'Accenture plc' 'Adobe Systems Inc'
#  'Analog Devices, Inc.' 'Archer-Daniels-Midland Co'
#  'Automatic Data Processing' 'Autodesk Inc' 'Ameren Corp'
#  'American Electric Power' 'AES Corp' 'AFLAC Inc'
#  'American International Group, Inc.' 'Assurant Inc'
#  'Arthur J. Gallagher & Co.' 'Akamai Technologies Inc' 'Albemarle Corp'
#  'Align Technology' 'Allstate Corp' 'Allegion' 'Applied Materials Inc'
#  'Advanced Micro Devices Inc' 'AMETEK Inc' 'Amgen Inc'
#  'Ameriprise Financial' 'American Tower Corp A' 'Amazon.com Inc' 'ANSYS'
#  'Aon plc' 'A.O. Smith Corp' 'Apache Corporation'
#  'Air Products & Chemicals Inc' 'Amphenol Corp' 'Aptiv Plc'
#  'Alexandria Real Estate Equities Inc' 'AvalonBay Communities, Inc.'
#  'Broadcom' 'Avery Dennison Corp' 'American Water Works Company Inc'
#  'American Express Co' 'AutoZone Inc' 'Boeing Company'
#  'Bank of America Corp' 'Baxter International Inc.' 'Best Buy Co. Inc.'
#  'Becton Dickinson' 'Franklin Resources' 'Biogen Inc.'
#  'The Bank of New York Mellon Corp.' 'BlackRock' 'Bristol-Myers Squibb'
#  'Boston Scientific' 'BorgWarner' 'Boston Properties' 'Citigroup Inc.'
#  'Conagra Brands' 'Cardinal Health Inc.' 'Caterpillar Inc.'
#  'Chubb Limited' 'CBOE Holdings' 'Crown Castle International Corp.'
#  'Carnival Corp.' 'Cadence Design Systems' 'CF Industries Holdings Inc'
#  'Citizens Financial Group' 'Church & Dwight' 'C. H. Robinson Worldwide'
#  'Charter Communications' 'CIGNA Corp.' 'Cincinnati Financial'
#  'Colgate-Palmolive' 'The Clorox Company' 'Comcast Corp.' 'CME Group Inc.'
#  'Chipotle Mexican Grill' 'Cummins Inc.' 'CMS Energy'
#  'Centene Corporation' 'CenterPoint Energy' 'Capital One Financial'
#  'The Cooper Companies' 'ConocoPhillips' 'Costco Wholesale Corp.'
#  'Campbell Soup' 'Salesforce.com' 'Cisco Systems' 'CSX Corp.'
#  'Cintas Corporation' 'Cognizant Technology Solutions' 'CVS Health'
#  'Chevron Corp.' 'Dominion Energy' 'Delta Air Lines Inc.' 'Deere & Co.'
#  'Discover Financial Services' 'Dollar General' 'Quest Diagnostics'
#  'D. R. Horton' 'Danaher Corp.' 'The Walt Disney Company'
#  'Digital Realty Trust Inc' 'Dollar Tree' 'Dover Corp.'
#  'Darden Restaurants' 'DTE Energy Co.' 'Duke Energy' 'DaVita Inc.'
#  'Devon Energy Corp.' 'Electronic Arts' 'eBay Inc.' 'Ecolab Inc.'
#  'Consolidated Edison' 'Equifax Inc.' "Edison Int'l" 'Estee Lauder Cos.'
#  'Eastman Chemical' 'Emerson Electric Company' 'EOG Resources' 'Equinix'
#  'Equity Residential' 'EQT Corporation' 'Eversource Energy'
#  'Essex Property Trust, Inc.' 'Eaton Corporation' 'Entergy Corp.'
#  'Edwards Lifesciences' 'Exelon Corp.' 'Expeditors International'
#  'Expedia Inc.' 'Extra Space Storage' 'Ford Motor' 'Fastenal Co'
#  'Freeport-McMoRan Inc.' 'FedEx Corporation' 'FirstEnergy Corp'
#  'F5 Networks' 'Fidelity National Information Services'
#  'Fifth Third Bancorp' 'FMC Corporation'
#  'Twenty-First Century Fox Class B' 'Twenty-First Century Fox Class A'
#  'Federal Realty Investment Trust' 'Fortive Corp' 'General Dynamics'
#  'General Electric' 'Gilead Sciences' 'General Mills' 'Corning Inc.'
#  'General Motors' 'Alphabet Inc Class C' 'Alphabet Inc Class A'
#  'Genuine Parts' 'Global Payments Inc.' 'Garmin Ltd.'
#  'Goldman Sachs Group' 'Grainger (W.W.) Inc.' 'Halliburton Co.'
#  'Hasbro Inc.' 'Huntington Bancshares' 'HCA Holdings' 'Home Depot'
#  'Hess Corporation' 'Hartford Financial Svc.Gp.'
#  'Huntington Ingalls Industries' 'Hilton Worldwide Holdings Inc' 'Hologic'
#  "Honeywell Int'l Inc." 'Hewlett Packard Enterprise' 'HP Inc.'
#  'Hormel Foods Corp.' 'Henry Schein' 'Host Hotels & Resorts'
#  'The Hershey Company' 'Humana Inc.' 'International Business Machines'
#  'Intercontinental Exchange' 'IDEXX Laboratories'
#  'Intl Flavors & Fragrances' 'Incyte' 'Intel Corp.' 'Intuit Inc.'
#  'International Paper' 'Interpublic Group' 'IQVIA Holdings Inc.'
#  'Ingersoll-Rand PLC' 'Iron Mountain Incorporated'
#  'Intuitive Surgical Inc.' 'Gartner Inc' 'Illinois Tool Works'
#  'Invesco Ltd.' 'J. B. Hunt Transport Services'
#  'Johnson Controls International' 'Johnson & Johnson' 'Juniper Networks'
#  'JPMorgan Chase & Co.' 'Kellogg Co.' 'KeyCorp' 'Kraft Heinz Co'
#  'Kimco Realty' 'KLA-Tencor Corp.' 'Kimberly-Clark' 'Kinder Morgan'
#  'Carmax Inc' 'Coca-Cola Company (The)' 'Kroger Co.' 'Loews Corp.'
#  'Lennar Corp.' 'Laboratory Corp. of America Holding' 'LKQ Corporation'
#  'Lilly (Eli) & Co.' 'Lockheed Martin Corp.' 'Alliant Energy Corp'
#  "Lowe's Cos." 'Lam Research' 'Southwest Airlines' 'LyondellBasell'
#  'Mastercard Inc.' 'Mid-America Apartments' "Marriott Int'l."
#  'Masco Corp.' "McDonald's Corp." 'Microchip Technology' 'McKesson Corp.'
#  "Moody's Corp" 'Mondelez International' 'Medtronic plc' 'MetLife Inc.'
#  'MGM Resorts International' 'Mohawk Industries' 'McCormick & Co.'
#  'Martin Marietta Materials' 'Marsh & McLennan' '3M Company'
#  'Monster Beverage' 'Altria Group Inc' 'The Mosaic Company'
#  'Marathon Petroleum' 'Merck & Co.' 'Marathon Oil Corp.' 'Morgan Stanley'
#  'Microsoft Corp.' 'Motorola Solutions Inc.' 'M&T Bank Corp.'
#  'Mettler Toledo' 'Micron Technology' 'Norwegian Cruise Line'
#  'Nasdaq, Inc.' 'NextEra Energy' 'Newmont Mining Corporation'
#  'Netflix Inc.' 'NiSource Inc.' 'Nike' 'Northrop Grumman Corp.'
#  'NRG Energy' 'Norfolk Southern Corp.' 'NetApp' 'Northern Trust Corp.'
#  'Nucor Corp.' 'Nvidia Corporation' 'News Corp. Class B'
#  'News Corp. Class A' 'Realty Income Corporation' 'ONEOK' 'Omnicom Group'
#  'Oracle Corp.' "O'Reilly Automotive" 'Occidental Petroleum'
#  'Paychex Inc.' 'PACCAR Inc.' 'PG&E Corp.' 'Public Serv. Enterprise Inc.'
#  'PepsiCo Inc.' 'Pfizer Inc.' 'Principal Financial Group'
#  'Procter & Gamble' 'Progressive Corp.' 'Parker-Hannifin'
#  'Pulte Homes Inc.' 'Packaging Corporation of America' 'Prologis'
#  'Philip Morris International' 'PNC Financial Services' 'Pentair Ltd.'
#  'Pinnacle West Capital' 'PPG Industries' 'PPL Corp.'
#  'Prudential Financial' 'Public Storage' 'Phillips 66'
#  'Quanta Services Inc.' 'PayPal' 'QUALCOMM Inc.' 'Qorvo'
#  'Royal Caribbean Cruises Ltd' 'Regency Centers Corporation' 'Regeneron'
#  'Regions Financial Corp.' 'Raymond James Financial Inc.'
#  'Polo Ralph Lauren Corp.' 'ResMed' 'Rockwell Automation Inc.'
#  'Roper Technologies' 'Ross Stores' 'Republic Services Inc'
#  'SBA Communications' 'Starbucks Corp.' 'Charles Schwab Corporation'
#  'Sherwin-Williams' 'JM Smucker' 'Schlumberger Ltd.' 'Snap-On Inc.'
#  'Synopsys Inc.' 'Southern Co.' 'Simon Property Group Inc'
#  'S&P Global, Inc.' 'Sempra Energy' 'State Street Corp.'
#  'Seagate Technology' 'Constellation Brands' 'Stanley Black & Decker'
#  'Skyworks Solutions' 'Synchrony Financial' 'Stryker Corp.' 'Sysco Corp.'
#  'AT&T Inc' 'Molson Coors Brewing Company' 'TransDigm Group'
#  'TE Connectivity Ltd.' 'Target Corp.' 'TJX Companies Inc.'
#  'Thermo Fisher Scientific' 'Tapestry, Inc.' 'T. Rowe Price Group'
#  'The Travelers Companies Inc.' 'Tractor Supply Company' 'Tyson Foods'
#  'Texas Instruments' 'Textron Inc.' 'United Continental Holdings'
#  'UDR Inc' 'Universal Health Services, Inc.'
#  'Ulta Salon Cosmetics & Fragrance Inc' 'United Health Group Inc.'
#  'Union Pacific' 'United Parcel Service' 'United Rentals, Inc.'
#  'U.S. Bancorp' 'Visa Inc.' 'Valero Energy' 'Vulcan Materials'
#  'Verisk Analytics' 'Verisign Inc.' 'Vertex Pharmaceuticals Inc'
#  'Ventas Inc' 'Verizon Communications' 'Waters Corporation'
#  'Walgreens Boots Alliance' 'Western Digital' 'Wec Energy Group Inc'
#  'Wells Fargo' 'Waste Management Inc.' 'Williams Cos.' 'Wal-Mart Stores'
#  'Weyerhaeuser Corp.' 'Wynn Resorts Ltd' 'Xcel Energy Inc'
#  'Exxon Mobil Corp.' 'Xylem Inc.' 'Yum! Brands Inc'
#  'Zimmer Biomet Holdings' 'Zoetis']
# Unique Values in 'name_short':
# ['Agilent Technologies, Inc.' 'American Airlines Group, Inc.' 'Apple Inc.'
#  'AbbVie Inc.' 'Abbott Laboratories' 'Accenture plc' 'Adobe Inc.'
#  'Analog Devices, Inc.' 'Archer-Daniels-Midland Company'
#  'Automatic Data Processing, Inc.' 'Autodesk, Inc.' 'Ameren Corporation'
#  'American Electric Power Company' 'The AES Corporation'
#  'AFLAC Incorporated' 'American International Group, I' 'Assurant, Inc.'
#  'Arthur J. Gallagher & Co.' 'Akamai Technologies, Inc.'
#  'Albemarle Corporation' 'Align Technology, Inc.'
#  'Allstate Corporation (The)' 'Allegion plc' 'Applied Materials, Inc.'
#  'Advanced Micro Devices, Inc.' 'AMETEK, Inc.' 'Amgen Inc.'
#  'Ameriprise Financial, Inc.' 'American Tower Corporation (REI'
#  'Amazon.com, Inc.' 'ANSYS, Inc.' 'Aon plc' 'A.O. Smith Corporation'
#  'APA Corporation' 'Air Products and Chemicals, Inc'
#  'Amphenol Corporation' 'Aptiv PLC' 'Alexandria Real Estate Equities'
#  'AvalonBay Communities, Inc.' 'Broadcom Inc.'
#  'Avery Dennison Corporation' 'American Water Works Company, I'
#  'American Express Company' 'AutoZone, Inc.' 'Boeing Company (The)'
#  'Bank of America Corporation' 'Baxter International Inc.'
#  'Best Buy Co., Inc.' 'Becton, Dickinson and Company'
#  'Franklin Resources, Inc.' 'Biogen Inc.'
#  'The Bank of New York Mellon Cor' 'BlackRock, Inc.'
#  'Bristol-Myers Squibb Company' 'Boston Scientific Corporation'
#  'BorgWarner Inc.' 'BXP, Inc.' 'Citigroup, Inc.' 'ConAgra Brands, Inc.'
#  'Cardinal Health, Inc.' 'Caterpillar, Inc.' 'Chubb Limited'
#  'Cboe Global Markets, Inc.' 'Crown Castle Inc.' 'Carnival Corporation'
#  'Cadence Design Systems, Inc.' 'CF Industries Holdings, Inc.'
#  'Citizens Financial Group, Inc.' 'Church & Dwight Company, Inc.'
#  'C.H. Robinson Worldwide, Inc.' 'Charter Communications, Inc.'
#  'The Cigna Group' 'Cincinnati Financial Corporatio'
#  'Colgate-Palmolive Company' 'Clorox Company (The)' 'Comcast Corporation'
#  'CME Group Inc.' 'Chipotle Mexican Grill, Inc.' 'Cummins Inc.'
#  'CMS Energy Corporation' 'Centene Corporation'
#  'CenterPoint Energy, Inc (Holdin' 'Capital One Financial Corporati'
#  'The Cooper Companies, Inc.' 'ConocoPhillips'
#  'Costco Wholesale Corporation' 'Campbell Soup Company' 'Salesforce, Inc.'
#  'Cisco Systems, Inc.' 'CSX Corporation' 'Cintas Corporation'
#  'Cognizant Technology Solutions ' 'CVS Health Corporation'
#  'Chevron Corporation' 'Dominion Energy, Inc.' 'Delta Air Lines, Inc.'
#  'Deere & Company' 'Discover Financial Services'
#  'Dollar General Corporation' 'Quest Diagnostics Incorporated'
#  'D.R. Horton, Inc.' 'Danaher Corporation' 'Walt Disney Company (The)'
#  'Digital Realty Trust, Inc.' 'Dollar Tree, Inc.' 'Dover Corporation'
#  'Darden Restaurants, Inc.' 'DTE Energy Company'
#  'Duke Energy Corporation (Holdin' 'DaVita Inc.'
#  'Devon Energy Corporation' 'Electronic Arts Inc.' 'eBay Inc.'
#  'Ecolab Inc.' 'Consolidated Edison, Inc.' 'Equifax, Inc.'
#  'Edison International' 'Estee Lauder Companies, Inc. (T'
#  'Eastman Chemical Company' 'Emerson Electric Company'
#  'EOG Resources, Inc.' 'Equinix, Inc.' 'Equity Residential'
#  'EQT Corporation' 'Eversource Energy (D/B/A)'
#  'Essex Property Trust, Inc.' 'Eaton Corporation, PLC'
#  'Entergy Corporation' 'Edwards Lifesciences Corporatio'
#  'Exelon Corporation' 'Expeditors International of Was'
#  'Expedia Group, Inc.' 'Extra Space Storage Inc' 'Ford Motor Company'
#  'Fastenal Company' 'Freeport-McMoRan, Inc.' 'FedEx Corporation'
#  'FirstEnergy Corp.' 'F5, Inc.' 'Fidelity National Information S'
#  'Fifth Third Bancorp' 'FMC Corporation' 'Fox Corporation'
#  'Federal Realty Investment Trust' 'Fortive Corporation'
#  'General Dynamics Corporation' 'GE Aerospace' 'Gilead Sciences, Inc.'
#  'General Mills, Inc.' 'Corning Incorporated' 'General Motors Company'
#  'Alphabet Inc.' 'Genuine Parts Company' 'Global Payments Inc.'
#  'Garmin Ltd.' 'Goldman Sachs Group, Inc. (The)' 'W.W. Grainger, Inc.'
#  'Halliburton Company' 'Hasbro, Inc.' 'Huntington Bancshares Incorpora'
#  'HCA Healthcare, Inc.' 'Home Depot, Inc. (The)' 'Hess Corporation'
#  'Hartford Financial Services Gro' 'Huntington Ingalls Industries, '
#  'Hilton Worldwide Holdings Inc.' 'Hologic, Inc.'
#  'Honeywell International Inc.' 'Hewlett Packard Enterprise Comp'
#  'HP Inc.' 'Hormel Foods Corporation' 'Henry Schein, Inc.'
#  'Host Hotels & Resorts, Inc.' 'The Hershey Company' 'Humana Inc.'
#  'International Business Machines' 'Intercontinental Exchange Inc.'
#  'IDEXX Laboratories, Inc.' 'International Flavors & Fragran'
#  'Incyte Corporation' 'Intel Corporation' 'Intuit Inc.'
#  'International Paper Company' 'Interpublic Group of Companies,'
#  'IQVIA Holdings, Inc.' 'Ingersoll Rand Inc.'
#  'Iron Mountain Incorporated (Del' 'Intuitive Surgical, Inc.'
#  'Gartner, Inc.' 'Illinois Tool Works Inc.' 'Invesco Ltd'
#  'J.B. Hunt Transport Services, I' 'Johnson Controls International '
#  'Johnson & Johnson' 'Juniper Networks, Inc.' 'JP Morgan Chase & Co.'
#  'Kellanova' 'KeyCorp' 'The Kraft Heinz Company'
#  'Kimco Realty Corporation (HC)' 'KLA Corporation'
#  'Kimberly-Clark Corporation' 'Kinder Morgan, Inc.' 'CarMax Inc'
#  'Coca-Cola Company (The)' 'Kroger Company (The)' 'Loews Corporation'
#  'Lennar Corporation' 'Labcorp Holdings Inc.' 'LKQ Corporation'
#  'Eli Lilly and Company' 'Lockheed Martin Corporation'
#  'Alliant Energy Corporation' "Lowe's Companies, Inc."
#  'Lam Research Corporation' 'Southwest Airlines Company'
#  'LyondellBasell Industries NV' 'Mastercard Incorporated'
#  'Mid-America Apartment Communiti' 'Marriott International'
#  'Masco Corporation' "McDonald's Corporation"
#  'Microchip Technology Incorporat' 'McKesson Corporation'
#  "Moody's Corporation" 'Mondelez International, Inc.' 'Medtronic plc.'
#  'MetLife, Inc.' 'MGM Resorts International' 'Mohawk Industries, Inc.'
#  'McCormick & Company, Incorporat' 'Martin Marietta Materials, Inc.'
#  'Marsh & McLennan Companies, Inc' '3M Company'
#  'Monster Beverage Corporation' 'Altria Group, Inc.'
#  'Mosaic Company (The)' 'Marathon Petroleum Corporation'
#  'Merck & Company, Inc.' 'Marathon Oil Corporation' 'Morgan Stanley'
#  'Microsoft Corporation' 'Motorola Solutions, Inc.' 'M&T Bank Corporation'
#  'Mettler-Toledo International, I' 'Micron Technology, Inc.'
#  'Norwegian Cruise Line Holdings ' 'Nasdaq, Inc.' 'NextEra Energy, Inc.'
#  'Newmont Corporation' 'Netflix, Inc.' 'NiSource Inc' 'Nike, Inc.'
#  'Northrop Grumman Corporation' 'NRG Energy, Inc.'
#  'Norfolk Southern Corporation' 'NetApp, Inc.'
#  'Northern Trust Corporation' 'Nucor Corporation' 'NVIDIA Corporation'
#  'News Corporation' 'Realty Income Corporation' 'ONEOK, Inc.'
#  'Omnicom Group Inc.' 'Oracle Corporation' "O'Reilly Automotive, Inc."
#  'Occidental Petroleum Corporatio' 'Paychex, Inc.' 'PACCAR Inc.'
#  'Pacific Gas & Electric Co.' 'Public Service Enterprise Group'
#  'Pepsico, Inc.' 'Pfizer, Inc.' 'Principal Financial Group Inc'
#  'Procter & Gamble Company (The)' 'Progressive Corporation (The)'
#  'Parker-Hannifin Corporation' 'PulteGroup, Inc.'
#  'Packaging Corporation of Americ' 'Prologis, Inc.'
#  'Philip Morris International Inc' 'PNC Financial Services Group, I'
#  'Pentair plc.' 'Pinnacle West Capital Corporati' 'PPG Industries, Inc.'
#  'PPL Corporation' 'Prudential Financial, Inc.' 'Public Storage'
#  'Phillips 66' 'Quanta Services, Inc.' 'PayPal Holdings, Inc.'
#  'QUALCOMM Incorporated' 'Qorvo, Inc.' 'Royal Caribbean Cruises Ltd.'
#  'Regency Centers Corporation' 'Regeneron Pharmaceuticals, Inc.'
#  'Regions Financial Corporation' 'Raymond James Financial, Inc.'
#  'Ralph Lauren Corporation' 'ResMed Inc.' 'Rockwell Automation, Inc.'
#  'Roper Technologies, Inc.' 'Ross Stores, Inc.' 'Republic Services, Inc.'
#  'SBA Communications Corporation' 'Starbucks Corporation'
#  'Charles Schwab Corporation (The' 'Sherwin-Williams Company (The)'
#  'The J.M. Smucker Company' 'Schlumberger N.V.' 'Snap-On Incorporated'
#  'Synopsys, Inc.' 'Southern Company (The)' 'Simon Property Group, Inc.'
#  'S&P Global Inc.' 'DBA Sempra' 'State Street Corporation'
#  'Seagate Technology Holdings PLC' 'Constellation Brands, Inc.'
#  'Stanley Black & Decker, Inc.' 'Skyworks Solutions, Inc.'
#  'Synchrony Financial' 'Stryker Corporation' 'Sysco Corporation'
#  'AT&T Inc.' 'Molson Coors Beverage Company'
#  'Transdigm Group Incorporated' 'TE Connectivity Ltd. New Switze'
#  'Target Corporation' 'TJX Companies, Inc. (The)'
#  'Thermo Fisher Scientific Inc' 'Tapestry, Inc.'
#  'T. Rowe Price Group, Inc.' 'The Travelers Companies, Inc.'
#  'Tractor Supply Company' 'Tyson Foods, Inc.'
#  'Texas Instruments Incorporated' 'Textron Inc.'
#  'United Airlines Holdings, Inc.' 'UDR, Inc.'
#  'Universal Health Services, Inc.' 'Ulta Beauty, Inc.'
#  'UnitedHealth Group Incorporated' 'Union Pacific Corporation'
#  'United Parcel Service, Inc.' 'United Rentals, Inc.' 'U.S. Bancorp'
#  'Visa Inc.' 'Valero Energy Corporation' 'Vulcan Materials Company (Holdi'
#  'Verisk Analytics, Inc.' 'VeriSign, Inc.'
#  'Vertex Pharmaceuticals Incorpor' 'Ventas, Inc.'
#  'Verizon Communications Inc.' 'Waters Corporation'
#  'Walgreens Boots Alliance, Inc.' 'Western Digital Corporation'
#  'WEC Energy Group, Inc.' 'Wells Fargo & Company' 'Waste Management, Inc.'
#  'Williams Companies, Inc. (The)' 'Walmart Inc.' 'Weyerhaeuser Company'
#  'Wynn Resorts, Limited' 'Xcel Energy Inc.' 'Exxon Mobil Corporation'
#  'Xylem Inc.' 'Yum! Brands, Inc.' 'Zimmer Biomet Holdings, Inc.'
#  'Zoetis Inc.']
# Unique Values in 'name_long':
# ['Agilent Technologies, Inc.' 'American Airlines Group Inc.' 'Apple Inc.'
#  'AbbVie Inc.' 'Abbott Laboratories' 'Accenture plc' 'Adobe Inc.'
#  'Analog Devices, Inc.' 'Archer-Daniels-Midland Company'
#  'Automatic Data Processing, Inc.' 'Autodesk, Inc.' 'Ameren Corporation'
#  'American Electric Power Company, Inc.' 'The AES Corporation'
#  'Aflac Incorporated' 'American International Group, Inc.'
#  'Assurant, Inc.' 'Arthur J. Gallagher & Co.' 'Akamai Technologies, Inc.'
#  'Albemarle Corporation' 'Align Technology, Inc.'
#  'The Allstate Corporation' 'Allegion plc' 'Applied Materials, Inc.'
#  'Advanced Micro Devices, Inc.' 'AMETEK, Inc.' 'Amgen Inc.'
#  'Ameriprise Financial, Inc.' 'American Tower Corporation'
#  'Amazon.com, Inc.' 'ANSYS, Inc.' 'Aon plc' 'A. O. Smith Corporation'
#  'APA Corporation' 'Air Products and Chemicals, Inc.'
#  'Amphenol Corporation' 'Aptiv PLC'
#  'Alexandria Real Estate Equities, Inc.' 'AvalonBay Communities, Inc.'
#  'Broadcom Inc.' 'Avery Dennison Corporation'
#  'American Water Works Company, Inc.' 'American Express Company'
#  'AutoZone, Inc.' 'The Boeing Company' 'Bank of America Corporation'
#  'Baxter International Inc.' 'Best Buy Co., Inc.'
#  'Becton, Dickinson and Company' 'Franklin Resources, Inc.' 'Biogen Inc.'
#  'The Bank of New York Mellon Corporation' 'BlackRock, Inc.'
#  'Bristol-Myers Squibb Company' 'Boston Scientific Corporation'
#  'BorgWarner Inc.' 'BXP, Inc.' 'Citigroup Inc.' 'Conagra Brands, Inc.'
#  'Cardinal Health, Inc.' 'Caterpillar Inc.' 'Chubb Limited'
#  'Cboe Global Markets, Inc.' 'Crown Castle Inc.'
#  'Carnival Corporation & plc' 'Cadence Design Systems, Inc.'
#  'CF Industries Holdings, Inc.' 'Citizens Financial Group, Inc.'
#  'Church & Dwight Co., Inc.' 'C.H. Robinson Worldwide, Inc.'
#  'Charter Communications, Inc.' 'The Cigna Group'
#  'Cincinnati Financial Corporation' 'Colgate-Palmolive Company'
#  'The Clorox Company' 'Comcast Corporation' 'CME Group Inc.'
#  'Chipotle Mexican Grill, Inc.' 'Cummins Inc.' 'CMS Energy Corporation'
#  'Centene Corporation' 'CenterPoint Energy, Inc.'
#  'Capital One Financial Corporation' 'The Cooper Companies, Inc.'
#  'ConocoPhillips' 'Costco Wholesale Corporation' 'Campbell Soup Company'
#  'Salesforce, Inc.' 'Cisco Systems, Inc.' 'CSX Corporation'
#  'Cintas Corporation' 'Cognizant Technology Solutions Corporation'
#  'CVS Health Corporation' 'Chevron Corporation' 'Dominion Energy, Inc.'
#  'Delta Air Lines, Inc.' 'Deere & Company' 'Discover Financial Services'
#  'Dollar General Corporation' 'Quest Diagnostics Incorporated'
#  'D.R. Horton, Inc.' 'Danaher Corporation' 'The Walt Disney Company'
#  'Digital Realty Trust, Inc.' 'Dollar Tree, Inc.' 'Dover Corporation'
#  'Darden Restaurants, Inc.' 'DTE Energy Company' 'Duke Energy Corporation'
#  'DaVita Inc.' 'Devon Energy Corporation' 'Electronic Arts Inc.'
#  'eBay Inc.' 'Ecolab Inc.' 'Consolidated Edison, Inc.' 'Equifax Inc.'
#  'Edison International' 'The Estée Lauder Companies Inc.'
#  'Eastman Chemical Company' 'Emerson Electric Co.' 'EOG Resources, Inc.'
#  'Equinix, Inc.' 'Equity Residential' 'EQT Corporation'
#  'Eversource Energy' 'Essex Property Trust, Inc.' 'Eaton Corporation plc'
#  'Entergy Corporation' 'Edwards Lifesciences Corporation'
#  'Exelon Corporation' 'Expeditors International of Washington, Inc.'
#  'Expedia Group, Inc.' 'Extra Space Storage Inc.' 'Ford Motor Company'
#  'Fastenal Company' 'Freeport-McMoRan Inc.' 'FedEx Corporation'
#  'FirstEnergy Corp.' 'F5, Inc.'
#  'Fidelity National Information Services, Inc.' 'Fifth Third Bancorp'
#  'FMC Corporation' 'Fox Corporation' 'Federal Realty Investment Trust'
#  'Fortive Corporation' 'General Dynamics Corporation' 'GE Aerospace'
#  'Gilead Sciences, Inc.' 'General Mills, Inc.' 'Corning Incorporated'
#  'General Motors Company' 'Alphabet Inc.' 'Genuine Parts Company'
#  'Global Payments Inc.' 'Garmin Ltd.' 'The Goldman Sachs Group, Inc.'
#  'W.W. Grainger, Inc.' 'Halliburton Company' 'Hasbro, Inc.'
#  'Huntington Bancshares Incorporated' 'HCA Healthcare, Inc.'
#  'The Home Depot, Inc.' 'Hess Corporation'
#  'The Hartford Financial Services Group, Inc.'
#  'Huntington Ingalls Industries, Inc.' 'Hilton Worldwide Holdings Inc.'
#  'Hologic, Inc.' 'Honeywell International Inc.'
#  'Hewlett Packard Enterprise Company' 'HP Inc.' 'Hormel Foods Corporation'
#  'Henry Schein, Inc.' 'Host Hotels & Resorts, Inc.' 'The Hershey Company'
#  'Humana Inc.' 'International Business Machines Corporation'
#  'Intercontinental Exchange, Inc.' 'IDEXX Laboratories, Inc.'
#  'International Flavors & Fragrances Inc.' 'Incyte Corporation'
#  'Intel Corporation' 'Intuit Inc.' 'International Paper Company'
#  'The Interpublic Group of Companies, Inc.' 'IQVIA Holdings Inc.'
#  'Ingersoll Rand Inc.' 'Iron Mountain Incorporated'
#  'Intuitive Surgical, Inc.' 'Gartner, Inc.' 'Illinois Tool Works Inc.'
#  'Invesco Ltd.' 'J.B. Hunt Transport Services, Inc.'
#  'Johnson Controls International plc' 'Johnson & Johnson'
#  'Juniper Networks, Inc.' 'JPMorgan Chase & Co.' 'Kellanova' 'KeyCorp'
#  'The Kraft Heinz Company' 'Kimco Realty Corporation' 'KLA Corporation'
#  'Kimberly-Clark Corporation' 'Kinder Morgan, Inc.' 'CarMax, Inc.'
#  'The Coca-Cola Company' 'The Kroger Co.' 'Loews Corporation'
#  'Lennar Corporation' 'Labcorp Holdings Inc.' 'LKQ Corporation'
#  'Eli Lilly and Company' 'Lockheed Martin Corporation'
#  'Alliant Energy Corporation' "Lowe's Companies, Inc."
#  'Lam Research Corporation' 'Southwest Airlines Co.'
#  'LyondellBasell Industries N.V.' 'Mastercard Incorporated'
#  'Mid-America Apartment Communities, Inc.' 'Marriott International, Inc.'
#  'Masco Corporation' "McDonald's Corporation"
#  'Microchip Technology Incorporated' 'McKesson Corporation'
#  "Moody's Corporation" 'Mondelez International, Inc.' 'Medtronic plc'
#  'MetLife, Inc.' 'MGM Resorts International' 'Mohawk Industries, Inc.'
#  'McCormick & Company, Incorporated' 'Martin Marietta Materials, Inc.'
#  'Marsh & McLennan Companies, Inc.' '3M Company'
#  'Monster Beverage Corporation' 'Altria Group, Inc.' 'The Mosaic Company'
#  'Marathon Petroleum Corporation' 'Merck & Co., Inc.'
#  'Marathon Oil Corporation' 'Morgan Stanley' 'Microsoft Corporation'
#  'Motorola Solutions, Inc.' 'M&T Bank Corporation'
#  'Mettler-Toledo International Inc.' 'Micron Technology, Inc.'
#  'Norwegian Cruise Line Holdings Ltd.' 'Nasdaq, Inc.'
#  'NextEra Energy, Inc.' 'Newmont Corporation' 'Netflix, Inc.'
#  'NiSource Inc.' 'NIKE, Inc.' 'Northrop Grumman Corporation'
#  'NRG Energy, Inc.' 'Norfolk Southern Corporation' 'NetApp, Inc.'
#  'Northern Trust Corporation' 'Nucor Corporation' 'NVIDIA Corporation'
#  'News Corporation' 'Realty Income Corporation' 'ONEOK, Inc.'
#  'Omnicom Group Inc.' 'Oracle Corporation' "O'Reilly Automotive, Inc."
#  'Occidental Petroleum Corporation' 'Paychex, Inc.' 'PACCAR Inc'
#  'PG&E Corporation' 'Public Service Enterprise Group Incorporated'
#  'PepsiCo, Inc.' 'Pfizer Inc.' 'Principal Financial Group, Inc.'
#  'The Procter & Gamble Company' 'The Progressive Corporation'
#  'Parker-Hannifin Corporation' 'PulteGroup, Inc.'
#  'Packaging Corporation of America' 'Prologis, Inc.'
#  'Philip Morris International Inc.'
#  'The PNC Financial Services Group, Inc.' 'Pentair plc'
#  'Pinnacle West Capital Corporation' 'PPG Industries, Inc.'
#  'PPL Corporation' 'Prudential Financial, Inc.' 'Public Storage'
#  'Phillips 66' 'Quanta Services, Inc.' 'PayPal Holdings, Inc.'
#  'QUALCOMM Incorporated' 'Qorvo, Inc.' 'Royal Caribbean Cruises Ltd.'
#  'Regency Centers Corporation' 'Regeneron Pharmaceuticals, Inc.'
#  'Regions Financial Corporation' 'Raymond James Financial, Inc.'
#  'Ralph Lauren Corporation' 'ResMed Inc.' 'Rockwell Automation, Inc.'
#  'Roper Technologies, Inc.' 'Ross Stores, Inc.' 'Republic Services, Inc.'
#  'SBA Communications Corporation' 'Starbucks Corporation'
#  'The Charles Schwab Corporation' 'The Sherwin-Williams Company'
#  'The J. M. Smucker Company' 'Schlumberger Limited' 'Snap-on Incorporated'
#  'Synopsys, Inc.' 'The Southern Company' 'Simon Property Group, Inc.'
#  'S&P Global Inc.' 'Sempra' 'State Street Corporation'
#  'Seagate Technology Holdings plc' 'Constellation Brands, Inc.'
#  'Stanley Black & Decker, Inc.' 'Skyworks Solutions, Inc.'
#  'Synchrony Financial' 'Stryker Corporation' 'Sysco Corporation'
#  'AT&T Inc.' 'Molson Coors Beverage Company'
#  'TransDigm Group Incorporated' 'TE Connectivity Ltd.'
#  'Target Corporation' 'The TJX Companies, Inc.'
#  'Thermo Fisher Scientific Inc.' 'Tapestry, Inc.'
#  'T. Rowe Price Group, Inc.' 'The Travelers Companies, Inc.'
#  'Tractor Supply Company' 'Tyson Foods, Inc.'
#  'Texas Instruments Incorporated' 'Textron Inc.'
#  'United Airlines Holdings, Inc.' 'UDR, Inc.'
#  'Universal Health Services, Inc.' 'Ulta Beauty, Inc.'
#  'UnitedHealth Group Incorporated' 'Union Pacific Corporation'
#  'United Parcel Service, Inc.' 'United Rentals, Inc.' 'U.S. Bancorp'
#  'Visa Inc.' 'Valero Energy Corporation' 'Vulcan Materials Company'
#  'Verisk Analytics, Inc.' 'VeriSign, Inc.'
#  'Vertex Pharmaceuticals Incorporated' 'Ventas, Inc.'
#  'Verizon Communications Inc.' 'Waters Corporation'
#  'Walgreens Boots Alliance, Inc.' 'Western Digital Corporation'
#  'WEC Energy Group, Inc.' 'Wells Fargo & Company' 'Waste Management, Inc.'
#  'The Williams Companies, Inc.' 'Walmart Inc.' 'Weyerhaeuser Company'
#  'Wynn Resorts, Limited' 'Xcel Energy Inc.' 'Exxon Mobil Corporation'
#  'Xylem Inc.' 'Yum! Brands, Inc.' 'Zimmer Biomet Holdings, Inc.'
#  'Zoetis Inc.']

# %%
import pandas as pd

# Load your cleaned dataset
# Example: cleaned_df = pd.read_csv('path_to_cleaned_data.csv')

# Define the columns to keep
columns_to_keep = ['Symbol', 'name', 'name_short', 'name_long']

# Drop columns that are not in the columns_to_keep list
cleaned_df = cleaned_df[columns_to_keep]

# Display the updated DataFrame to confirm the changes
print("Updated Dataset with Relevant Columns:")
print(cleaned_df.head())
# Out:
# Updated Dataset with Relevant Columns:
#   Symbol                      name                     name_short  \
# 0      A  Agilent Technologies Inc     Agilent Technologies, Inc.
# 1    AAL   American Airlines Group  American Airlines Group, Inc.
# 3   AAPL                Apple Inc.                     Apple Inc.
# 4   ABBV               AbbVie Inc.                    AbbVie Inc.
# 7    ABT       Abbott Laboratories            Abbott Laboratories
#
#                       name_long
# 0    Agilent Technologies, Inc.
# 1  American Airlines Group Inc.
# 3                    Apple Inc.
# 4                   AbbVie Inc.
# 7           Abbott Laboratories

# %%
print("Columns in the cleaned dataset:")
print(cleaned_df.columns)
# Out:
# Columns in the cleaned dataset:
# Index(['Symbol', 'name', 'name_short', 'name_long'], dtype='object')

# %%
# Remove duplicate rows based on 'symbol'
cleaned_df = cleaned_df.drop_duplicates(subset='Symbol')

# Verify that duplicates are removed
print("Number of duplicate rows removed:", cleaned_df.duplicated(subset='Symbol').sum())
# Out:
# Number of duplicate rows removed: 0

# %%
# Define a function to compare names
def compare_names(name1, name2):
    return fuzz.ratio(name1, name2)

# Apply fuzzy matching for shortname and longname
cleaned_df['name_short_similarity'] = cleaned_df.apply(
    lambda row: compare_names(row['name'], row['name_short']) if pd.notna(row['name']) and pd.notna(row['name_short']) else None,
    axis=1
)

cleaned_df['name_long_similarity'] = cleaned_df.apply(
    lambda row: compare_names(row['name'], row['name_long']) if pd.notna(row['name']) and pd.notna(row['name_long']) else None,
    axis=1
)

# Display the updated DataFrame with similarity scores
print("Dataset with Fuzzy Matching Results:")
print(cleaned_df.head())
# Out:
# Dataset with Fuzzy Matching Results:
#   Symbol                      name                     name_short  \
# 0      A  Agilent Technologies Inc     Agilent Technologies, Inc.
# 1    AAL   American Airlines Group  American Airlines Group, Inc.
# 3   AAPL                Apple Inc.                     Apple Inc.
# 4   ABBV               AbbVie Inc.                    AbbVie Inc.
# 7    ABT       Abbott Laboratories            Abbott Laboratories
#
#                       name_long  name_short_similarity  name_long_similarity
# 0    Agilent Technologies, Inc.                     96                    96
# 1  American Airlines Group Inc.                     88                    90
# 3                    Apple Inc.                    100                   100
# 4                   AbbVie Inc.                    100                   100
# 7           Abbott Laboratories                    100                   100

# %%
# Example threshold
threshold = 80

# Identify potential matches based on similarity score
cleaned_df['name_short_match'] = cleaned_df['name_short_similarity'] >= threshold
cleaned_df['name_long_match'] = cleaned_df['name_long_similarity'] >= threshold

print("Potential Matches Based on Similarity Scores:")
print(cleaned_df[['Symbol', 'name', 'name_short', 'name_long', 'name_short_similarity', 'name_long_similarity', 'name_short_match', 'name_long_match']].head())
# Out:
# Potential Matches Based on Similarity Scores:
#   Symbol                      name                     name_short  \
# 0      A  Agilent Technologies Inc     Agilent Technologies, Inc.
# 1    AAL   American Airlines Group  American Airlines Group, Inc.
# 3   AAPL                Apple Inc.                     Apple Inc.
# 4   ABBV               AbbVie Inc.                    AbbVie Inc.
# 7    ABT       Abbott Laboratories            Abbott Laboratories
#
#                       name_long  name_short_similarity  name_long_similarity  \
# 0    Agilent Technologies, Inc.                     96                    96
# 1  American Airlines Group Inc.                     88                    90
# 3                    Apple Inc.                    100                   100
# 4                   AbbVie Inc.                    100                   100
# 7           Abbott Laboratories                    100                   100
#
#    name_short_match  name_long_match
# 0              True             True
# 1              True             True
# 3              True             True
# 4              True             True
# 7              True             True

# %%
# Example true labels and predictions
# Replace these with your actual data
true_labels = [1, 0, 1, 1, 0]  # Example true labels
predictions = [1, 0, 0, 1, 1]  # Example predictions

# Calculate metrics
precision = precision_score(true_labels, predictions)
recall = recall_score(true_labels, predictions)
f1 = f1_score(true_labels, predictions)

print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Precision: 0.6666666666666666
# Recall: 0.6666666666666666
# F1 Score: 0.6666666666666666
